# %% [markdown]
# # FLOPs 측정을 위한 라이브러리 설치
# * FLOPs는 train, test 모두 측정함.
#     * 학습 시의 FLOPs 측정은 모델이 경량화 되었는지 확인하기 위함.
#     * 테스트 시 FLOPs 측정은 이 모델을 통해 실제 추론 시에 컴퓨팅 단위 소비가 줄었는지 확인하기 위함.

# %%
pip install thop
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Train

# %%
# !python train.py --network mobile0.25
# Out:
# Printing net...
# RetinaFace(
#   (body): IntermediateLayerGetter(
#     (stage1): Sequential(
#       (0): Sequential(
#         (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#         (3): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#       (2): Sequential(
# ...

# %% [markdown]
# # Test

# %%
# !python test_widerface.py --trained_model ./weights/mobilenet0.25_Final.pth --network mobile0.25
# Out:
# Loading pretrained model from ./weights/mobilenet0.25_Final.pth
# remove prefix 'module.'
# Missing keys:113
# Unused checkpoint keys:417
# Used keys:255
# Finished loading model!
# RetinaFace(
#   (body): IntermediateLayerGetter(
#     (stage1): Sequential(
#       (0): Sequential(
#         (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=8, bias=False)
#         (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.1, inplace=True)
#         (3): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...
